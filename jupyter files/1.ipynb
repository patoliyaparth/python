# %%
import pandas as pd
csv_1=pd.read_csv("student_info.csv")
csv_1
# Out:
#    Unnamed: 0    name    city  marks
# 0           0   harry  rampur     92
# 1           1   rohan   delhi     98
# 2           2  skillf  mandva     89
# 3           3   shubh  bhesan     91

# %%
csv_2=pd.read_csv("ipl.csv")
csv_2
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0          Dwayne Bravo       10   34.2    206    16  18.69   299      -
# 1      Mukesh Choudhary       13   45.3    273    16  26.50   424      1
# 2    Maheesh Theekshana        9   35.0    210    12  21.75   261      1
# 3             Moeen Ali       10   23.5    143     8  19.75   158      -
# 4       Ravindra Jadeja       10   33.0    198     5  49.60   248      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 97       Alzarri Joseph        9   30.0    180     7  37.71   264      -
# 98       R. Sai Kishore        5   16.0     96     6  20.17   121      -
# 99      Pradeep Sangwan        3    9.0     54     3  21.67    65      -
# 100         Varun Aaron        2    5.0     30     2  26.00    52      -
# 101    Darshan Nalkande        2    5.1     31     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
# ..     ...
# ...

# %%
csv_2=pd.read_csv("ipl.csv",nrows=3)
csv_2
# Out:
#                Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers 5-fers
# 0        Dwayne Bravo       10   34.2    206    16  18.69   299      -      -
# 1    Mukesh Choudhary       13   45.3    273    16  26.50   424      1      -
# 2  Maheesh Theekshana        9   35.0    210    12  21.75   261      1      -

# %%
csv_2=pd.read_csv("ipl.csv",usecols=['Player'])
csv_2
# Out:
#                  Player
# 0          Dwayne Bravo
# 1      Mukesh Choudhary
# 2    Maheesh Theekshana
# 3             Moeen Ali
# 4       Ravindra Jadeja
# ..                  ...
# 97       Alzarri Joseph
# 98       R. Sai Kishore
# 99      Pradeep Sangwan
# 100         Varun Aaron
# 101    Darshan Nalkande
#
# [102 rows x 1 columns]

# %%
csv_2=pd.read_csv("ipl.csv",skiprows=[1])
csv_2
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0      Mukesh Choudhary       13   45.3    273    16  26.50   424      1
# 1    Maheesh Theekshana        9   35.0    210    12  21.75   261      1
# 2             Moeen Ali       10   23.5    143     8  19.75   158      -
# 3       Ravindra Jadeja       10   33.0    198     5  49.60   248      -
# 4      Mitchell Santner        6   19.0    114     4  32.50   130      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 96       Alzarri Joseph        9   30.0    180     7  37.71   264      -
# 97       R. Sai Kishore        5   16.0     96     6  20.17   121      -
# 98      Pradeep Sangwan        3    9.0     54     3  21.67    65      -
# 99          Varun Aaron        2    5.0     30     2  26.00    52      -
# 100    Darshan Nalkande        2    5.1     31     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
# ..     ...
# ...

# %%
csv_2=pd.read_csv("ipl.csv",index_col='Player')
csv_2
# Out:
#                     Matches  Overs  Balls  Wkts    Avg  Runs 4-fers 5-fers
# Player
# Dwayne Bravo             10   34.2    206    16  18.69   299      -      -
# Mukesh Choudhary         13   45.3    273    16  26.50   424      1      -
# Maheesh Theekshana        9   35.0    210    12  21.75   261      1      -
# Moeen Ali                10   23.5    143     8  19.75   158      -      -
# Ravindra Jadeja          10   33.0    198     5  49.60   248      -      -
# ...                     ...    ...    ...   ...    ...   ...    ...    ...
# Alzarri Joseph            9   30.0    180     7  37.71   264      -      -
# R. Sai Kishore            5   16.0     96     6  20.17   121      -      -
# Pradeep Sangwan           3    9.0     54     3  21.67    65      -      -
# Varun Aaron               2    5.0     30     2  26.00    52      -      -
# Darshan Nalkande          2    5.1     31     2  29.50    59      -      -
#
# [102 rows x 8 columns]

# %%
csv_2=pd.read_csv("ipl.csv",header=2)
csv_2
# Out:
#       Mukesh Choudhary  13  45.3  273  16   26.5  424  1  -
# 0   Maheesh Theekshana   9  35.0  210  12  21.75  261  1  -
# 1            Moeen Ali  10  23.5  143   8  19.75  158  -  -
# 2      Ravindra Jadeja  10  33.0  198   5  49.60  248  -  -
# 3     Mitchell Santner   6  19.0  114   4  32.50  130  -  -
# 4      Simarjeet Singh   6  18.0  108   4  34.50  138  -  -
# ..                 ...  ..   ...  ...  ..    ...  ... .. ..
# 95      Alzarri Joseph   9  30.0  180   7  37.71  264  -  -
# 96      R. Sai Kishore   5  16.0   96   6  20.17  121  -  -
# 97     Pradeep Sangwan   3   9.0   54   3  21.67   65  -  -
# 98         Varun Aaron   2   5.0   30   2  26.00   52  -  -
# 99    Darshan Nalkande   2   5.1   31   2  29.50   59  -  -
#
# [100 rows x 9 columns]

# %%
csv_2=pd.read_csv("ipl.csv",dtype={"Balls":"float"})
csv_2
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0          Dwayne Bravo       10   34.2  206.0    16  18.69   299      -
# 1      Mukesh Choudhary       13   45.3  273.0    16  26.50   424      1
# 2    Maheesh Theekshana        9   35.0  210.0    12  21.75   261      1
# 3             Moeen Ali       10   23.5  143.0     8  19.75   158      -
# 4       Ravindra Jadeja       10   33.0  198.0     5  49.60   248      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 97       Alzarri Joseph        9   30.0  180.0     7  37.71   264      -
# 98       R. Sai Kishore        5   16.0   96.0     6  20.17   121      -
# 99      Pradeep Sangwan        3    9.0   54.0     3  21.67    65      -
# 100         Varun Aaron        2    5.0   30.0     2  26.00    52      -
# 101    Darshan Nalkande        2    5.1   31.0     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
# ..     ...
# ...

# %%
csv_2=pd.read_csv("ipl.csv",header=None,Prefix="col")
csv_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 csv_2=pd.read_csv("ipl.csv",header=None,Prefix="col")
#       2 csv_2
#
# TypeError: read_csv() got an unexpected keyword argument 'Prefix'

# %%
csv_2.index
# Out:
# RangeIndex(start=0, stop=102, step=1)

# %%
csv_2.columns
# Out:
# Index(['Player', 'Matches', 'Overs', 'Balls', 'Wkts', 'Avg', 'Runs', '4-fers',
#        '5-fers'],
#       dtype='object')

# %%
csv_2.describe
# Out:
# <bound method NDFrame.describe of                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0          Dwayne Bravo       10   34.2  206.0    16  18.69   299      -
# 1      Mukesh Choudhary       13   45.3  273.0    16  26.50   424      1
# 2    Maheesh Theekshana        9   35.0  210.0    12  21.75   261      1
# 3             Moeen Ali       10   23.5  143.0     8  19.75   158      -
# 4       Ravindra Jadeja       10   33.0  198.0     5  49.60   248      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 97       Alzarri Joseph        9   30.0  180.0     7  37.71   264      -
# 98       R. Sai Kishore        5   16.0   96.0     6  20.17   121      -
# 99      Pradeep Sangwan        3    9.0   54.0     3  21.67    65      -
# 100         Varun Aaron        2    5.0   30.0     2  26.00    52      -
# 101    Darshan Nalkande        2    5.1   31.0     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# ...

# %%
csv_2.head()
# Out:
#                Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers 5-fers
# 0        Dwayne Bravo       10   34.2  206.0    16  18.69   299      -      -
# 1    Mukesh Choudhary       13   45.3  273.0    16  26.50   424      1      -
# 2  Maheesh Theekshana        9   35.0  210.0    12  21.75   261      1      -
# 3           Moeen Ali       10   23.5  143.0     8  19.75   158      -      -
# 4     Ravindra Jadeja       10   33.0  198.0     5  49.60   248      -      -

# %%
csv_2.head(2)
# Out:
#              Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers 5-fers
# 0      Dwayne Bravo       10   34.2  206.0    16  18.69   299      -      -
# 1  Mukesh Choudhary       13   45.3  273.0    16  26.50   424      1      -

# %%
csv_2.tail(2)
# Out:
#                Player  Matches  Overs  Balls  Wkts   Avg  Runs 4-fers 5-fers
# 100       Varun Aaron        2    5.0   30.0     2  26.0    52      -      -
# 101  Darshan Nalkande        2    5.1   31.0     2  29.5    59      -      -

# %%
csv_2[2:10]
# Out:
#                 Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers 5-fers
# 2   Maheesh Theekshana        9   35.0  210.0    12  21.75   261      1      -
# 3            Moeen Ali       10   23.5  143.0     8  19.75   158      -      -
# 4      Ravindra Jadeja       10   33.0  198.0     5  49.60   248      -      -
# 5     Mitchell Santner        6   19.0  114.0     4  32.50   130      -      -
# 6      Simarjeet Singh        6   18.0  108.0     4  34.50   138      -      -
# 7     Prashant Solanki        2    6.0   36.0     2  19.00    38      -      -
# 8  Matheesha Pathirana        2    6.5   41.0     2  26.00    52      -      -
# 9         Chris Jordan        4   12.5   77.0     2  67.50   135      -      -

# %%
csv_2.to_numpy()
# Out:
# array([['Dwayne Bravo', 10, 34.2, 206.0, 16, 18.69, 299, '-', '-'],
#        ['Mukesh Choudhary', 13, 45.3, 273.0, 16, 26.5, 424, '1', '-'],
#        ['Maheesh Theekshana', 9, 35.0, 210.0, 12, 21.75, 261, '1', '-'],
#        ['Moeen Ali', 10, 23.5, 143.0, 8, 19.75, 158, '-', '-'],
#        ['Ravindra Jadeja', 10, 33.0, 198.0, 5, 49.6, 248, '-', '-'],
#        ['Mitchell Santner', 6, 19.0, 114.0, 4, 32.5, 130, '-', '-'],
#        ['Simarjeet Singh', 6, 18.0, 108.0, 4, 34.5, 138, '-', '-'],
#        ['Prashant Solanki', 2, 6.0, 36.0, 2, 19.0, 38, '-', '-'],
#        ['Matheesha Pathirana', 2, 6.5, 41.0, 2, 26.0, 52, '-', '-'],
#        ['Chris Jordan', 4, 12.5, 77.0, 2, 67.5, 135, '-', '-'],
#        ['Tushar Deshpande', 2, 7.0, 42.0, 1, 63.0, 63, '-', '-'],
#        ['Wanindu Hasaranga', 16, 57.0, 342.0, 26, 16.54, 430, '1', '1'],
#        ['Josh Hazlewood', 12, 46.3, 279.0, 20, 18.85, 377, '1', '-'],
#        ['Harshal Patel', 15, 53.3, 321.0, 19, 21.58, 410, '1', '-'],
# ...

# %%
csv_2.sort_index(axis=0,ascending=False)
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 101    Darshan Nalkande        2    5.1   31.0     2  29.50    59      -
# 100         Varun Aaron        2    5.0   30.0     2  26.00    52      -
# 99      Pradeep Sangwan        3    9.0   54.0     3  21.67    65      -
# 98       R. Sai Kishore        5   16.0   96.0     6  20.17   121      -
# 97       Alzarri Joseph        9   30.0  180.0     7  37.71   264      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 4       Ravindra Jadeja       10   33.0  198.0     5  49.60   248      -
# 3             Moeen Ali       10   23.5  143.0     8  19.75   158      -
# 2    Maheesh Theekshana        9   35.0  210.0    12  21.75   261      1
# 1      Mukesh Choudhary       13   45.3  273.0    16  26.50   424      1
# 0          Dwayne Bravo       10   34.2  206.0    16  18.69   299      -
#
#     5-fers
# 101      -
# 100      -
# 99       -
# 98       -
# 97       -
# ..     ...
# ...

# %%
csv_2.loc[0,"Player"]="patricks"
csv_2
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0              patricks       10   34.2  206.0    16  18.69   299      -
# 1      Mukesh Choudhary       13   45.3  273.0    16  26.50   424      1
# 2    Maheesh Theekshana        9   35.0  210.0    12  21.75   261      1
# 3             Moeen Ali       10   23.5  143.0     8  19.75   158      -
# 4       Ravindra Jadeja       10   33.0  198.0     5  49.60   248      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 97       Alzarri Joseph        9   30.0  180.0     7  37.71   264      -
# 98       R. Sai Kishore        5   16.0   96.0     6  20.17   121      -
# 99      Pradeep Sangwan        3    9.0   54.0     3  21.67    65      -
# 100         Varun Aaron        2    5.0   30.0     2  26.00    52      -
# 101    Darshan Nalkande        2    5.1   31.0     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
# ..     ...
# ...

# %%
csv_2.loc[[2,3],["Player","Matches"]]
# Out:
#                Player  Matches
# 2  Maheesh Theekshana        9
# 3           Moeen Ali       10

# %%
csv_2.iloc[0,2]
# Out:
# 34.2

# %%
csv_2.drop("Runs",axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 csv_2.drop("Runs",axis=0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
# ...

# %%
csv_2.dropna(axis=0)
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0              patricks       10   34.2  206.0    16  18.69   299      -
# 1      Mukesh Choudhary       13   45.3  273.0    16  26.50   424      1
# 2    Maheesh Theekshana        9   35.0  210.0    12  21.75   261      1
# 3             Moeen Ali       10   23.5  143.0     8  19.75   158      -
# 4       Ravindra Jadeja       10   33.0  198.0     5  49.60   248      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 97       Alzarri Joseph        9   30.0  180.0     7  37.71   264      -
# 98       R. Sai Kishore        5   16.0   96.0     6  20.17   121      -
# 99      Pradeep Sangwan        3    9.0   54.0     3  21.67    65      -
# 100         Varun Aaron        2    5.0   30.0     2  26.00    52      -
# 101    Darshan Nalkande        2    5.1   31.0     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
# ..     ...
# ...

# %%
import pandas as pd
csv_2=pd.read_csv("ipl.csv")
csv_2
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0          Dwayne Bravo       10   34.2    206    16  18.69   299      -
# 1      Mukesh Choudhary       13   45.3    273    16  26.50   424      1
# 2    Maheesh Theekshana        9   35.0    210    12  21.75   261      1
# 3             Moeen Ali       10   23.5    143     8  19.75   158      -
# 4       Ravindra Jadeja       10   33.0    198     5  49.60   248      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 97       Alzarri Joseph        9   30.0    180     7  37.71   264      -
# 98       R. Sai Kishore        5   16.0     96     6  20.17   121      -
# 99      Pradeep Sangwan        3    9.0     54     3  21.67    65      -
# 100         Varun Aaron        2    5.0     30     2  26.00    52      -
# 101    Darshan Nalkande        2    5.1     31     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
# ..     ...
# ...

# %%
csv_2.fillna("python")
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0          Dwayne Bravo       10   34.2    206    16  18.69   299      -
# 1      Mukesh Choudhary       13   45.3    273    16  26.50   424      1
# 2    Maheesh Theekshana        9   35.0    210    12  21.75   261      1
# 3             Moeen Ali       10   23.5    143     8  19.75   158      -
# 4       Ravindra Jadeja       10   33.0    198     5  49.60   248      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 97       Alzarri Joseph        9   30.0    180     7  37.71   264      -
# 98       R. Sai Kishore        5   16.0     96     6  20.17   121      -
# 99      Pradeep Sangwan        3    9.0     54     3  21.67    65      -
# 100         Varun Aaron        2    5.0     30     2  26.00    52      -
# 101    Darshan Nalkande        2    5.1     31     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
# ..     ...
# ...

# %%
csv_2.fillna({"Player":"python","Runs":"java","Matches":"c++"})
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0          Dwayne Bravo       10   34.2    206    16  18.69   299      -
# 1      Mukesh Choudhary       13   45.3    273    16  26.50   424      1
# 2    Maheesh Theekshana        9   35.0    210    12  21.75   261      1
# 3             Moeen Ali       10   23.5    143     8  19.75   158      -
# 4       Ravindra Jadeja       10   33.0    198     5  49.60   248      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 97       Alzarri Joseph        9   30.0    180     7  37.71   264      -
# 98       R. Sai Kishore        5   16.0     96     6  20.17   121      -
# 99      Pradeep Sangwan        3    9.0     54     3  21.67    65      -
# 100         Varun Aaron        2    5.0     30     2  26.00    52      -
# 101    Darshan Nalkande        2    5.1     31     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
# ..     ...
# ...

# %%
# forward filling
csv_2.fillna(method="ffill")
# backward filling
csv_2.fillna(method="bfill")
# put any element where na present
csv_2.fillna(12,inplace=True)

# %%
csv_2.replace(to_replace="Dwayne Bravo",value="DJ bravo")
# Out:
#                  Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0              DJ bravo       10   34.2    206    16  18.69   299      -
# 1      Mukesh Choudhary       13   45.3    273    16  26.50   424      1
# 2    Maheesh Theekshana        9   35.0    210    12  21.75   261      1
# 3             Moeen Ali       10   23.5    143     8  19.75   158      -
# 4       Ravindra Jadeja       10   33.0    198     5  49.60   248      -
# ..                  ...      ...    ...    ...   ...    ...   ...    ...
# 97       Alzarri Joseph        9   30.0    180     7  37.71   264      -
# 98       R. Sai Kishore        5   16.0     96     6  20.17   121      -
# 99      Pradeep Sangwan        3    9.0     54     3  21.67    65      -
# 100         Varun Aaron        2    5.0     30     2  26.00    52      -
# 101    Darshan Nalkande        2    5.1     31     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# 4        -
# ..     ...
# ...

# %%
csv_2.replace("[A-Z]","HI",regex=True)
# Out:
#                    Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers  \
# 0          HIwayne HIravo       10   34.2    206    16  18.69   299      -
# 1      HIukesh HIhoudhary       13   45.3    273    16  26.50   424      1
# 2    HIaheesh HIheekshana        9   35.0    210    12  21.75   261      1
# 3             HIoeen HIli       10   23.5    143     8  19.75   158      -
# 4       HIavindra HIadeja       10   33.0    198     5  49.60   248      -
# ..                    ...      ...    ...    ...   ...    ...   ...    ...
# 97       HIlzarri HIoseph        9   30.0    180     7  37.71   264      -
# 98      HI. HIai HIishore        5   16.0     96     6  20.17   121      -
# 99      HIradeep HIangwan        3    9.0     54     3  21.67    65      -
# 100         HIarun HIaron        2    5.0     30     2  26.00    52      -
# 101    HIarshan HIalkande        2    5.1     31     2  29.50    59      -
#
#     5-fers
# 0        -
# 1        -
# 2        -
# 3        -
# ...

# %%
csv_2.replace({"Player":"[A-Z]"},22,regex=True)
# Out:
#      Player  Matches  Overs  Balls  Wkts    Avg  Runs 4-fers 5-fers
# 0        22       10   34.2    206    16  18.69   299      -      -
# 1        22       13   45.3    273    16  26.50   424      1      -
# 2        22        9   35.0    210    12  21.75   261      1      -
# 3        22       10   23.5    143     8  19.75   158      -      -
# 4        22       10   33.0    198     5  49.60   248      -      -
# ..      ...      ...    ...    ...   ...    ...   ...    ...    ...
# 97       22        9   30.0    180     7  37.71   264      -      -
# 98       22        5   16.0     96     6  20.17   121      -      -
# 99       22        3    9.0     54     3  21.67    65      -      -
# 100      22        2    5.0     30     2  26.00    52      -      -
# 101      22        2    5.1     31     2  29.50    59      -      -
#
# [102 rows x 9 columns]

# %%
csv_2.replace(1,method="bfill")
